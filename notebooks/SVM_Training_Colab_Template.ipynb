# %% [markdown]
# # Baseline SVM Training - Colab
#
# Notebook ini melatih baseline TF-IDF + SVM menggunakan dataset `pipeline2`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
PROJECT_DIR = '/content/drive/MyDrive/skripsi/pipeline2'
DATASET_CSV = f'{PROJECT_DIR}/artifacts/dataset_indobert256.csv'
OUTPUT_DIR = f'{PROJECT_DIR}/artifacts/baseline_svm'
TRAIN_SCRIPT = f'{PROJECT_DIR}/03_train_baseline_svm.py'

# %%
# !pip install -q pandas numpy scipy scikit-learn

# %%
# %run "{TRAIN_SCRIPT}" \
  --input-csv "{DATASET_CSV}" \
  --output-dir "{OUTPUT_DIR}"

# %% [markdown]
# Output baseline:
#
# - `artifacts/baseline_svm/baseline_bundle.pkl`
# - `artifacts/baseline_svm/metrics.json`
# - `artifacts/baseline_svm/test_predictions.csv`
#
# File `baseline_bundle.pkl` sudah siap dipakai untuk inferensi tanpa retrain.
